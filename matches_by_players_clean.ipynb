# %%
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Data\matches_by_players.csv"

# Read Purchasing File and store into Pandas data frame
matches_by_players = pd.read_csv(file_to_load)
matches_by_players.head()
# Out:
#                    match_id                   team_id team_region  \
# 0  6159ad3d143c37878b2384a9  6020bc8ef1e4807cc700391a     Oceania
# 1  6159ad3d143c37878b2384a9  6020bc8ef1e4807cc700391a     Oceania
# 2  6159ad3d143c37878b2384a9  6020bc8ef1e4807cc700391a     Oceania
# 3  6159ad3d143c37878b2384a9  614c8930f8090ec745286474     Oceania
# 4  6159ad3d143c37878b2384a9  614c8930f8090ec745286474     Oceania
#
#                   player_id    player_tag  core_shots  core_goals  core_saves  \
# 0  5f3d8fdd95f40596eae2412e        Amphis         9.0         3.0         4.0
# 1  5f3d8fdd95f40596eae23e01        Torsos        13.0         2.0         2.0
# 2  5f3d8fdd95f40596eae23e53       Express        12.0         4.0         2.0
# 3  5f7ca648ea8a0f0714fb9a20         Laxin         5.0         1.0         8.0
# 4  5f3d8fdd95f40596eae24503  Baked Potato         4.0         3.0         4.0
#
#    core_assists  core_score  ...  positioning_percent_most_back  \
# ...

# %%
matches_by_players.drop(columns=["advanced_rating"])
# Out:
#                        match_id                   team_id    team_region  \
# 0      6159ad3d143c37878b2384a9  6020bc8ef1e4807cc700391a        Oceania
# 1      6159ad3d143c37878b2384a9  6020bc8ef1e4807cc700391a        Oceania
# 2      6159ad3d143c37878b2384a9  6020bc8ef1e4807cc700391a        Oceania
# 3      6159ad3d143c37878b2384a9  614c8930f8090ec745286474        Oceania
# 4      6159ad3d143c37878b2384a9  614c8930f8090ec745286474        Oceania
# ...                         ...                       ...            ...
# 18101  6240dedac437fde7e02d2cd9  6020bc70f1e4807cc70023a5  North America
# 18102  6240dedac437fde7e02d2cd9  6020bc70f1e4807cc70023a5  North America
# 18103  6240dedac437fde7e02d2cd9  6020c2b7f1e4807cc702ac15         Europe
# 18104  6240dedac437fde7e02d2cd9  6020c2b7f1e4807cc702ac15         Europe
# 18105  6240dedac437fde7e02d2cd9  6020c2b7f1e4807cc702ac15         Europe
#
#                       player_id    player_tag  core_shots  core_goals  \
# ...

# %%
#Check for NaN and blank data
matches_by_players.isnull().sum()
# Out:
# match_id                         0
# team_id                          0
# team_region                      0
# player_id                        0
# player_tag                       0
#                               ...
# demo_taken                     138
# advanced_goal_participation      0
# advanced_rating                  0
# score                            0
# winner                           0
# Length: 90, dtype: int64

# %%
clean = matches_by_players.dropna()

# %%
clean.head()
# Out:
#                    match_id                   team_id team_region  \
# 0  6159ad3d143c37878b2384a9  6020bc8ef1e4807cc700391a     Oceania
# 1  6159ad3d143c37878b2384a9  6020bc8ef1e4807cc700391a     Oceania
# 2  6159ad3d143c37878b2384a9  6020bc8ef1e4807cc700391a     Oceania
# 3  6159ad3d143c37878b2384a9  614c8930f8090ec745286474     Oceania
# 4  6159ad3d143c37878b2384a9  614c8930f8090ec745286474     Oceania
#
#                   player_id    player_tag  core_shots  core_goals  core_saves  \
# 0  5f3d8fdd95f40596eae2412e        Amphis         9.0         3.0         4.0
# 1  5f3d8fdd95f40596eae23e01        Torsos        13.0         2.0         2.0
# 2  5f3d8fdd95f40596eae23e53       Express        12.0         4.0         2.0
# 3  5f7ca648ea8a0f0714fb9a20         Laxin         5.0         1.0         8.0
# 4  5f3d8fdd95f40596eae24503  Baked Potato         4.0         3.0         4.0
#
#    core_assists  core_score  ...  positioning_percent_most_back  \
# ...

# %%
clean.isnull().sum()
# Out:
# match_id                       0
# team_id                        0
# team_region                    0
# player_id                      0
# player_tag                     0
#                               ..
# demo_taken                     0
# advanced_goal_participation    0
# advanced_rating                0
# score                          0
# winner                         0
# Length: 90, dtype: int64

# %%
clean.to_csv('Data\clean\matches_by_players_clean.csv')
