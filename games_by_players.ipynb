# %%
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Data\games_by_players.csv"

# Read Purchasing File and store into Pandas data frame
games_by_players = pd.read_csv(file_to_load)
games_by_players.head()
# Out:
#                     game_id   color                   team_id team_region  \
# 0  616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a     Oceania
# 1  616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a     Oceania
# 2  616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a     Oceania
# 3  616004f3143c37878b238690  orange  614c8930f8090ec745286474     Oceania
# 4  616004f3143c37878b238690  orange  614c8930f8090ec745286474     Oceania
#
#                   player_id player_tag  core_shots  core_goals  core_saves  \
# 0  5f3d8fdd95f40596eae2412e     Amphis           4           1           1
# 1  5f3d8fdd95f40596eae23e01     Torsos           5           0           2
# 2  5f3d8fdd95f40596eae23e53    Express           4           1           0
# 3  604e562901d675f81a96b270    mel kin           2           0           6
# 4  5f7ca648ea8a0f0714fb9a20      Laxin           1           0           3
#
#    core_assists  ...  car_id  car_name  steering_sensitivity  camera_fov  \
# 0             0  ...  4284.0    Fennec                  3.05       110.0
# 1             1  ...   403.0   Dominus                  1.00       110.0
# 2             0  ...  4284.0    Fennec                  1.30       110.0
# 3             0  ...   403.0   Dominus                  1.51       110.0
# 4             0  ...    23.0    Octane                  1.75       110.0
#
#    camera_height  camera_pitch  camera_distance  camera_stiffness  \
# 0          100.0          -3.0            260.0              0.40
# 1          100.0          -2.0            250.0              0.55
# 2          100.0          -3.0            260.0              0.50
# 3           90.0          -4.0            280.0              0.30
# 4           90.0          -5.0            270.0              0.25
#
#    camera_swivel_speed  camera_transition_speed
# 0                  2.4                      1.2
# 1                 10.0                      1.4
# 2                  2.5                      1.2
# 3                  6.0                      1.0
# 4                 10.0                      1.0
#
# [5 rows x 103 columns]

# %%
for col in games_by_players.columns:
    print(col)
# Out:
# game_id
# color
# team_id
# team_region
# player_id
# player_tag
# core_shots
# core_goals
# core_saves
# core_assists
# core_score
# core_shooting_percentage
# boost_bpm
# boost_bcpm
# boost_avg_amount
# boost_amount_collected
# boost_amount_stolen
# boost_amount_collected_big
# boost_amount_stolen_big
# boost_amount_collected_small
# boost_amount_stolen_small
# boost_count_collected_big
# boost_count_stolen_big
# boost_count_collected_small
# boost_count_stolen_small
# boost_amount_overfill
# boost_amount_overfill_stolen
# boost_amount_used_while_supersonic
# boost_time_zero_boost
# boost_percent_zero_boost
# boost_time_full_boost
# boost_percent_full_boost
# boost_time_boost_0_25
# boost_time_boost_25_50
# boost_time_boost_50_75
# boost_time_boost_75_100
# boost_percent_boost_0_25
# boost_percent_boost_25_50
# boost_percent_boost_50_75
# boost_percent_boost_75_100
# movement_avg_speed
# movement_total_distance
# movement_time_supersonic_speed
# movement_time_boost_speed
# movement_time_slow_speed
# movement_time_ground
# movement_time_low_air
# movement_time_high_air
# movement_time_powerslide
# movement_count_powerslide
# movement_avg_powerslide_duration
# movement_avg_speed_percentage
# movement_percent_slow_speed
# movement_percent_boost_speed
# movement_percent_supersonic_speed
# movement_percent_ground
# movement_percent_low_air
# movement_percent_high_air
# positioning_avg_distance_to_ball
# positioning_avg_distance_to_ball_possession
# positioning_avg_distance_to_ball_no_possession
# positioning_avg_distance_to_mates
# positioning_time_defensive_third
# positioning_time_neutral_third
# positioning_time_offensive_third
# positioning_time_defensive_half
# positioning_time_offensive_half
# positioning_time_behind_ball
# positioning_time_in_front_ball
# positioning_time_most_back
# positioning_time_most_forward
# positioning_goals_against_while_last_defender
# positioning_time_closest_to_ball
# positioning_time_farthest_from_ball
# positioning_percent_defensive_third
# positioning_percent_offensive_third
# positioning_percent_neutral_third
# positioning_percent_defensive_half
# positioning_percent_offensive_half
# positioning_percent_behind_ball
# positioning_percent_in_front_ball
# positioning_percent_most_back
# positioning_percent_most_forward
# positioning_percent_closest_to_ball
# positioning_percent_farthest_from_ball
# demo_inflicted
# demo_taken
# advanced_goal_participation
# advanced_rating
# advanced_mvp
# winner
# platform
# platform_id
# car_id
# car_name
# steering_sensitivity
# camera_fov
# camera_height
# camera_pitch
# camera_distance
# camera_stiffness
# camera_swivel_speed
# camera_transition_speed

# %%
clean = games_by_players.drop(columns=["positioning_avg_distance_to_ball",
                                "positioning_avg_distance_to_ball_possession",
                                "positioning_avg_distance_to_ball_no_possession",
                                "positioning_avg_distance_to_mates",
                                "positioning_time_defensive_third",
                                "positioning_time_neutral_third",
                                "positioning_time_offensive_third",
                                "positioning_time_defensive_half",
                                "positioning_time_offensive_half",
                                "positioning_time_behind_ball",
                                "positioning_time_in_front_ball",
                                "positioning_time_most_back",
                                "positioning_time_most_forward",
                                "positioning_goals_against_while_last_defender",
                                "positioning_time_closest_to_ball",
                                "positioning_time_farthest_from_ball",
                                "positioning_percent_defensive_third",
                                "positioning_percent_offensive_third",
                                "positioning_percent_neutral_third",
                                "positioning_percent_defensive_half",
                                "positioning_percent_offensive_half",
                                "positioning_percent_behind_ball",
                                "positioning_percent_in_front_ball",
                                "positioning_percent_most_back",
                                "positioning_percent_most_forward",
                                "positioning_percent_closest_to_ball",
                                "positioning_percent_farthest_from_ball",
                                "camera_fov",
                                "camera_height",
                                "camera_pitch",
                                "camera_distance",
                                "camera_stiffness",
                                "camera_swivel_speed",
                                "camera_transition_speed",
                                "steering_sensitivity",
                                "movement_time_supersonic_speed",
                                "movement_time_boost_speed",
                                "movement_time_slow_speed",
                                "movement_time_ground",
                                "movement_time_low_air",
                                "movement_time_high_air",
                                "movement_time_powerslide",
                                "movement_count_powerslide",
                                "movement_avg_powerslide_duration",
                                "movement_avg_speed_percentage",
                                "movement_percent_slow_speed",
                                "movement_percent_boost_speed",
                                "movement_percent_supersonic_speed",
                                "movement_percent_ground",
                                "movement_percent_low_air",
                                "movement_percent_high_air"
                            ])

# %%
for col in clean.columns:
    print(col)
# Out:
# game_id
# color
# team_id
# team_region
# player_id
# player_tag
# core_shots
# core_goals
# core_saves
# core_assists
# core_score
# core_shooting_percentage
# boost_bpm
# boost_bcpm
# boost_avg_amount
# boost_amount_collected
# boost_amount_stolen
# boost_amount_collected_big
# boost_amount_stolen_big
# boost_amount_collected_small
# boost_amount_stolen_small
# boost_count_collected_big
# boost_count_stolen_big
# boost_count_collected_small
# boost_count_stolen_small
# boost_amount_overfill
# boost_amount_overfill_stolen
# boost_amount_used_while_supersonic
# boost_time_zero_boost
# boost_percent_zero_boost
# boost_time_full_boost
# boost_percent_full_boost
# boost_time_boost_0_25
# boost_time_boost_25_50
# boost_time_boost_50_75
# boost_time_boost_75_100
# boost_percent_boost_0_25
# boost_percent_boost_25_50
# boost_percent_boost_50_75
# boost_percent_boost_75_100
# movement_avg_speed
# movement_total_distance
# demo_inflicted
# demo_taken
# advanced_goal_participation
# advanced_rating
# advanced_mvp
# winner
# platform
# platform_id
# car_id
# car_name

# %%
clean.isnull().sum()
# Out:
# game_id                                 0
# color                                   0
# team_id                                 0
# team_region                             0
# player_id                               0
# player_tag                              0
# core_shots                              0
# core_goals                              0
# core_saves                              0
# core_assists                            0
# core_score                              0
# core_shooting_percentage                0
# boost_bpm                             840
# boost_bcpm                            840
# boost_avg_amount                      840
# boost_amount_collected                840
# boost_amount_stolen                   840
# boost_amount_collected_big            840
# boost_amount_stolen_big               840
# boost_amount_collected_small          840
# boost_amount_stolen_small             840
# boost_count_collected_big             840
# boost_count_stolen_big                840
# boost_count_collected_small           840
# boost_count_stolen_small              840
# boost_amount_overfill                 840
# boost_amount_overfill_stolen          840
# boost_amount_used_while_supersonic    840
# boost_time_zero_boost                 840
# boost_percent_zero_boost              840
# boost_time_full_boost                 840
# boost_percent_full_boost              840
# boost_time_boost_0_25                 840
# boost_time_boost_25_50                840
# boost_time_boost_50_75                840
# boost_time_boost_75_100               840
# boost_percent_boost_0_25              840
# boost_percent_boost_25_50             840
# boost_percent_boost_50_75             840
# boost_percent_boost_75_100            840
# movement_avg_speed                    840
# movement_total_distance               840
# demo_inflicted                        840
# demo_taken                            840
# advanced_goal_participation             0
# advanced_rating                         2
# advanced_mvp                            0
# winner                                  0
# platform                              912
# platform_id                           912
# car_id                                912
# car_name                              915
# dtype: int64

# %%
clean2 = clean.dropna()

# %%
clean2.isnull().sum()
# Out:
# game_id                               0
# color                                 0
# team_id                               0
# team_region                           0
# player_id                             0
# player_tag                            0
# core_shots                            0
# core_goals                            0
# core_saves                            0
# core_assists                          0
# core_score                            0
# core_shooting_percentage              0
# boost_bpm                             0
# boost_bcpm                            0
# boost_avg_amount                      0
# boost_amount_collected                0
# boost_amount_stolen                   0
# boost_amount_collected_big            0
# boost_amount_stolen_big               0
# boost_amount_collected_small          0
# boost_amount_stolen_small             0
# boost_count_collected_big             0
# boost_count_stolen_big                0
# boost_count_collected_small           0
# boost_count_stolen_small              0
# boost_amount_overfill                 0
# boost_amount_overfill_stolen          0
# boost_amount_used_while_supersonic    0
# boost_time_zero_boost                 0
# boost_percent_zero_boost              0
# boost_time_full_boost                 0
# boost_percent_full_boost              0
# boost_time_boost_0_25                 0
# boost_time_boost_25_50                0
# boost_time_boost_50_75                0
# boost_time_boost_75_100               0
# boost_percent_boost_0_25              0
# boost_percent_boost_25_50             0
# boost_percent_boost_50_75             0
# boost_percent_boost_75_100            0
# movement_avg_speed                    0
# movement_total_distance               0
# demo_inflicted                        0
# demo_taken                            0
# advanced_goal_participation           0
# advanced_rating                       0
# advanced_mvp                          0
# winner                                0
# platform                              0
# platform_id                           0
# car_id                                0
# car_name                              0
# dtype: int64

# %%
clean2.head()
# Out:
#                     game_id   color                   team_id team_region  \
# 0  616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a     Oceania
# 1  616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a     Oceania
# 2  616004f3143c37878b238690    blue  6020bc8ef1e4807cc700391a     Oceania
# 3  616004f3143c37878b238690  orange  614c8930f8090ec745286474     Oceania
# 4  616004f3143c37878b238690  orange  614c8930f8090ec745286474     Oceania
#
#                   player_id player_tag  core_shots  core_goals  core_saves  \
# 0  5f3d8fdd95f40596eae2412e     Amphis           4           1           1
# 1  5f3d8fdd95f40596eae23e01     Torsos           5           0           2
# 2  5f3d8fdd95f40596eae23e53    Express           4           1           0
# 3  604e562901d675f81a96b270    mel kin           2           0           6
# 4  5f7ca648ea8a0f0714fb9a20      Laxin           1           0           3
#
#    core_assists  ...  demo_inflicted  demo_taken  advanced_goal_participation  \
# 0             0  ...             0.0         0.0                         50.0
# 1             1  ...             1.0         0.0                         50.0
# 2             0  ...             0.0         3.0                         50.0
# 3             0  ...             2.0         0.0                          0.0
# 4             0  ...             0.0         0.0                          0.0
#
#    advanced_rating  advanced_mvp  winner  platform        platform_id  car_id  \
# 0         0.916465          True    True     steam  76561198180452118  4284.0
# 1         0.966440         False    True     steam  76561198052159821   403.0
# 2         0.781224         False    True     steam  76561198065500375  4284.0
# 3         0.824301         False   False     steam  76561199067761149   403.0
# 4         0.457923         False   False     steam  76561199073713301    23.0
#
#    car_name
# 0    Fennec
# 1   Dominus
# 2    Fennec
# 3   Dominus
# 4    Octane
#
# [5 rows x 52 columns]

# %%
clean2.to_csv('Data\clean\games_by_players_clean.csv')
