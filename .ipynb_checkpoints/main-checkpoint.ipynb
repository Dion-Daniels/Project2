# %%
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Data\main.csv"

# Read Purchasing File and store into Pandas data frame
main_data = pd.read_csv(file_to_load)
main_data.head()
# Out:
#                    event_id       event event_split event_region  \
# 0  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
# 1  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
# 2  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
# 3  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
# 4  614b7046f8090ec74528642d  Regional 1        Fall      Oceania
#
#                                           event_slug  \
# 0  https://octane.gg/events/642d-rlcs-2021-22-fal...
# 1  https://octane.gg/events/642d-rlcs-2021-22-fal...
# 2  https://octane.gg/events/642d-rlcs-2021-22-fal...
# 3  https://octane.gg/events/642d-rlcs-2021-22-fal...
# 4  https://octane.gg/events/642d-rlcs-2021-22-fal...
#
#             event_start_date             event_end_date event_tier  \
# 0  2021-10-07 23:00:00+00:00  2021-10-17 22:30:00+00:00          A
# 1  2021-10-07 23:00:00+00:00  2021-10-17 22:30:00+00:00          A
# 2  2021-10-07 23:00:00+00:00  2021-10-17 22:30:00+00:00          A
# 3  2021-10-07 23:00:00+00:00  2021-10-17 22:30:00+00:00          A
# 4  2021-10-07 23:00:00+00:00  2021-10-17 22:30:00+00:00          A
#
#               event_phase  prize_money  ...  reverse_sweep_attempt  \
# 0  Invitational Qualifier      30000.0  ...                  False
# 1  Invitational Qualifier      30000.0  ...                  False
# 2  Invitational Qualifier      30000.0  ...                  False
# 3  Invitational Qualifier      30000.0  ...                  False
# 4  Invitational Qualifier      30000.0  ...                  False
#
#   reverse_sweep                   game_id game_number  \
# 0         False  616004f3143c37878b238690         1.0
# 1         False  616004f7143c37878b238697         2.0
# 2         False  616004fc143c37878b23869e         3.0
# 3         False  61614e40f8090ec74528706b         1.0
# 4         False  61614e45143c37878b2387b8         2.0
#
#                    game_date  game_duration     map_id     map_name overtime  \
# 0  2021-10-08 06:08:23+00:00          300.0  stadium_p  DFH Stadium    False
# 1  2021-10-08 06:16:09+00:00          300.0  stadium_p  DFH Stadium    False
# 2  2021-10-08 06:23:31+00:00          326.0  stadium_p  DFH Stadium     True
# 3  2021-10-08 06:10:54+00:00          300.0  stadium_p  DFH Stadium    False
# 4  2021-10-08 06:18:58+00:00          300.0  stadium_p  DFH Stadium    False
#
#                          ballchasing_id
# 0  15f12bd9-f4a6-4cea-a2dc-610cd9dd976b
# 1  2f01deab-3f2f-412f-a70e-72b39b3b204a
# 2  3b0fc17c-6f8d-4e94-a625-e0fa988d7cc0
# 3  6e5e523a-3299-42d1-8b34-7ac0baa1b771
# 4  95bfed45-3271-407b-9188-a278dfa8f66e
#
# [5 rows x 36 columns]

# %%
for col in main_data.columns:
    print(col)
# Out:
# event_id
# event
# event_split
# event_region
# event_slug
# event_start_date
# event_end_date
# event_tier
# event_phase
# prize_money
# stage_step
# stage
# stage_start_date
# stage_end_date
# stage_is_lan
# stage_is_qualifier
# liquipedia_link
# location_venue
# location_city
# location_country
# match_id
# match_slug
# match_number
# match_round
# match_date
# match_format
# reverse_sweep_attempt
# reverse_sweep
# game_id
# game_number
# game_date
# game_duration
# map_id
# map_name
# overtime
# ballchasing_id

# %%
clean = main_data.drop(columns=["ballchasing_id", 
                                "event_split", 
                                "reverse_sweep_attempt", 
                                "reverse_sweep", 
                                "event_slug", 
                                "match_slug", 
                                "liquipedia_link"])

# %%
clean.isnull().sum()
# Out:
# event_id                  0
# event                     0
# event_region              0
# event_start_date          0
# event_end_date            0
# event_tier                0
# event_phase               0
# prize_money               0
# stage_step                0
# stage                     0
# stage_start_date          0
# stage_end_date            0
# stage_is_lan              0
# stage_is_qualifier        0
# location_venue        12502
# location_city         12502
# location_country      12502
# match_id                  0
# match_number              0
# match_round               0
# match_date                0
# match_format              0
# game_id                 664
# game_number             664
# game_date               804
# game_duration           664
# map_id                  804
# map_name                747
# overtime                664
# dtype: int64

# %%
clean2 = clean.dropna()

# %%
clean2.head()
# Out:
#                       event_id  event event_region           event_start_date  \
# 6354  614b6589f8090ec745286426  Major        World  2021-12-08 00:00:00+00:00
# 6355  614b6589f8090ec745286426  Major        World  2021-12-08 00:00:00+00:00
# 6356  614b6589f8090ec745286426  Major        World  2021-12-08 00:00:00+00:00
# 6357  614b6589f8090ec745286426  Major        World  2021-12-08 00:00:00+00:00
# 6358  614b6589f8090ec745286426  Major        World  2021-12-08 00:00:00+00:00
#
#                  event_end_date event_tier event_phase  prize_money  \
# 6354  2021-12-12 23:30:00+00:00          S  Main Event     300000.0
# 6355  2021-12-12 23:30:00+00:00          S  Main Event     300000.0
# 6356  2021-12-12 23:30:00+00:00          S  Main Event     300000.0
# 6357  2021-12-12 23:30:00+00:00          S  Main Event     300000.0
# 6358  2021-12-12 23:30:00+00:00          S  Main Event     300000.0
#
#       stage_step        stage  ... match_round                 match_date  \
# 6354           0  Swiss Stage  ...     Round 1  2021-12-08 17:00:00+00:00
# 6355           0  Swiss Stage  ...     Round 1  2021-12-08 17:00:00+00:00
# 6356           0  Swiss Stage  ...     Round 1  2021-12-08 17:00:00+00:00
# 6357           0  Swiss Stage  ...     Round 1  2021-12-08 17:00:00+00:00
# 6358           0  Swiss Stage  ...     Round 1  2021-12-08 18:00:00+00:00
#
#       match_format                   game_id game_number  \
# 6354     best-of-5  61b0e7c7da9d7ca1c7ba35c4         1.0
# 6355     best-of-5  61b0ea50c437fde7e02cb0de         2.0
# 6356     best-of-5  61b0ebedda9d7ca1c7ba35cb         3.0
# 6357     best-of-5  61b0edc5da9d7ca1c7ba35d2         4.0
# 6358     best-of-5  61b0f7adda9d7ca1c7ba35f5         1.0
#
#                       game_date game_duration                map_id  \
# 6354  2021-12-08 17:13:09+00:00         300.0   eurostadium_night_p
# 6355  2021-12-08 17:24:05+00:00         512.0         chn_stadium_p
# 6356  2021-12-08 17:30:59+00:00         311.0             stadium_p
# 6357  2021-12-08 17:38:30+00:00         300.0  utopiastadium_dusk_p
# 6358  2021-12-08 18:20:50+00:00         300.0   eurostadium_night_p
#
#                     map_name overtime
# 6354       Mannfield (Night)    False
# 6355        Forbidden Temple     True
# 6356             DFH Stadium     True
# 6357  Utopia Coliseum (Dusk)    False
# 6358       Mannfield (Night)    False
#
# [5 rows x 29 columns]

# %%
clean2.isnull().sum()
# Out:
# event_id              0
# event                 0
# event_region          0
# event_start_date      0
# event_end_date        0
# event_tier            0
# event_phase           0
# prize_money           0
# stage_step            0
# stage                 0
# stage_start_date      0
# stage_end_date        0
# stage_is_lan          0
# stage_is_qualifier    0
# location_venue        0
# location_city         0
# location_country      0
# match_id              0
# match_number          0
# match_round           0
# match_date            0
# match_format          0
# game_id               0
# game_number           0
# game_date             0
# game_duration         0
# map_id                0
# map_name              0
# overtime              0
# dtype: int64

# %%
clean2.to_csv('Data\clean\main_clean.csv')
